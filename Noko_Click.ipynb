# %% [markdown]
# <a href="https://colab.research.google.com/github/Cybersoulja/hashnode-starter-kit2/blob/main/Noko_Click.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Getting** ***Started***

# %% [markdown]
# # **first things first**
#
#  don't let the interface fool you you won't have to learn all of this. There's really two main things that you need to know to get you started.

# %% [markdown]
# 1.   **Text** Block
# 2.   **Code** Block
#
# ![Black & Yellow Jewelry Shop Golden Modern Intro video Background Removed.png](data:image/png;base64,...)![IMG_7657.jpeg](data:image/jpeg;base64,...)
